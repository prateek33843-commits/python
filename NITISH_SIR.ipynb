# %%
#Accessing dictionary elements
print(car_dict{'brand'})
# Out:
#   File "/tmp/ipython-input-2553722259.py", line 2
#     print(car_dict{'brand'})
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
# for duplicate keys
 car_dict2={

 }
# Out:
#   File "/tmp/ipython-input-2746451515.py", line 2
#     car_dict2={
#     ^
# IndentationError: unexpected indent

# %%
# for Accesing Dict items
x=car_dict.get("model")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1595985757.py in <cell line: 0>()
#       1 # for Accesing Dict items
# ----> 2 x=car_dict.get("model")
#
# NameError: name 'car_dict' is not defined

# %%
#The keys() method
